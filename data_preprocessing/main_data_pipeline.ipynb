# %%
import pandas as pd
import numpy as np
from import_gdc import ImportGDC
from import_hpa import ImportHPA
from import_string import ImportSTRING
from import_dgn import ImportDGN
from create_node2vec_embeddings import Runnode2vec

# %% [markdown]
# Import National Institute of Health Genomic Data Commons (GDA) and Human Protein Atlas (HPA) Data

# %%
# !python --version
# Out:
# Python 3.9.16

# %%
# Process the gdc dataset to include only desired columns and scores
gdc = ImportGDC()
gdc
# Out:
#                ensembl  nih_ssm_in_cohort  nih_ssm_across_gdc  nih_cnv_gain  \
# 0      ENSG00000147481           0.144621            0.028155      0.076023
# 1      ENSG00000105877           0.144621            0.084772      0.074074
# 2      ENSG00000188107           0.144621            0.068585      0.111111
# 3      ENSG00000125414           0.144621            0.062601      0.005848
# 4      ENSG00000009694           0.144621            0.071653      0.052632
# ...                ...                ...                 ...           ...
# 21087  ENSG00000146648           0.146384            0.052244      0.105263
# 21088  ENSG00000133958           0.146384            0.059916      0.025341
# 21089  ENSG00000134376           0.146384            0.056617      0.085770
# 21090  ENSG00000109061           0.146384            0.057691      0.009747
# 21091  ENSG00000134516           0.146384            0.054622      0.066277
#
#        nih_cnv_loss  nih_tot_mutations
# 0          0.056530                 92
# 1          0.007797                105
# 2          0.056530                 95
# 3          0.042885                 95
# 4          0.025341                110
# ...             ...                ...
# 21087      0.019493                 51
# 21088      0.046784                110
# 21089      0.007797                 93
# 21090      0.040936                 93
# 21091      0.033138                103
#
# [21092 rows x 6 columns]

# %%
hpa = ImportHPA()
hpa
# Out:
# C:\Users\atieh\geneDRAGNN\data_preprocessing\import_hpa.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hpa_features["Tissue RNA - lung [NX]"] = (hpa_features["Tissue RNA - lung [NX]"] - hpa_features["Tissue RNA - lung [NX]"].mean()) / hpa_features["Tissue RNA - lung [NX]"].std()
# C:\Users\atieh\geneDRAGNN\data_preprocessing\import_hpa.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hpa_features[col] = (hpa_features[col] - hpa_features[col].mean()) / hpa_features[col].std()
#                ensembl     hpa_0     hpa_1     hpa_2     hpa_3     hpa_4  \
# 0      ENSG00000175899  0.443505  0.313574  0.430307 -0.285337 -0.351412
# 1      ENSG00000128274  0.532289  0.789331 -0.122159  0.019000  1.427162
# 2      ENSG00000094914  1.605229  0.936681  0.345886  0.183699 -1.001764
# 3      ENSG00000081760  0.467196  0.690415 -0.066723  0.335478  1.017124
# 4      ENSG00000114771  0.956718  0.202132 -0.490047 -0.524460  0.467132
# ...                ...       ...       ...       ...       ...       ...
# 15008  ENSG00000198455  1.436813 -1.455513  0.510199  0.224208  0.323736
# 15009  ENSG00000070476  1.140170 -1.162868  0.551409  0.127004  0.119115
# 15010  ENSG00000162378  0.782655 -0.057857 -0.397211  0.017498 -0.135123
# 15011  ENSG00000159840  1.042306  0.183392 -0.327697  0.065425 -0.459893
# 15012  ENSG00000074755  0.553160  0.068709  0.013208  0.760541  0.592771
#
#           hpa_5     hpa_6     hpa_7     hpa_8  ...    hpa_90    hpa_91  \
# 0      1.545059 -0.450936 -0.444200 -0.116774  ... -0.060338  0.084813
# 1     -0.065659  0.001669  0.386983 -0.028900  ... -0.114554 -0.175826
# 2     -0.846346  0.550995  0.368205  0.202731  ...  0.409659 -0.239592
# 3      0.029579 -0.131714  0.212387  0.075120  ...  0.018723  0.250506
# 4     -0.207775 -0.494652  0.192615  0.077836  ... -0.002920  0.005087
# ...         ...       ...       ...       ...  ...       ...       ...
# 15008 -0.171141 -0.060697  0.088626  0.103071  ... -0.044920 -0.041646
# 15009 -0.120434 -0.421260  0.798186  0.041917  ... -0.032211 -0.047264
# 15010 -0.248882 -0.438176  0.113363 -0.295955  ...  0.009041 -0.018390
# 15011  0.507171 -0.610148  0.067066  0.368216  ...  0.306923  0.111694
# 15012 -0.094544  0.326136 -0.636445  0.047971  ... -0.002350 -0.012895
#
#          hpa_92    hpa_93    hpa_94    hpa_95    hpa_96    hpa_97    hpa_98  \
# 0     -0.123304 -0.108172  0.237750  0.169390 -0.337498  0.316335 -0.147962
# 1     -0.043692  0.170677  0.057589 -0.161377 -0.112053  0.056161 -0.032347
# 2     -0.096925 -0.181151 -0.250948  0.210805  0.036100  0.342006 -0.033900
# 3      0.121457 -0.228074  0.058906 -0.054963 -0.016087  0.117175  0.116624
# 4      0.006484  0.005054 -0.005735 -0.006768 -0.001066  0.007657 -0.018742
# ...         ...       ...       ...       ...       ...       ...       ...
# 15008 -0.009279 -0.021875  0.001084  0.030362 -0.020984  0.005424 -0.012979
# 15009 -0.000765 -0.009255  0.010864  0.030472 -0.025857  0.004240 -0.008338
# 15010  0.003542  0.031033  0.037414  0.026793  0.046815  0.003799  0.011371
# 15011 -0.351023 -0.155401  0.376688 -0.123091 -0.176505 -0.039884 -0.090115
# 15012  0.009867  0.000370 -0.000915 -0.000043 -0.011993 -0.002164 -0.009043
#
#          hpa_99
# 0     -0.007512
# 1     -0.022306
# 2      0.423577
# 3      0.204021
# 4      0.001135
# ...         ...
# 15008 -0.002219
# 15009 -0.015161
# 15010  0.035801
# 15011 -0.019298
# 15012  0.003843
#
# [15013 rows x 101 columns]

# %%
master = hpa.merge(gdc, on="ensembl")
master
# Out:
#                ensembl     hpa_0     hpa_1     hpa_2     hpa_3     hpa_4  \
# 0      ENSG00000175899  0.443505  0.313574  0.430307 -0.285337 -0.351412
# 1      ENSG00000128274  0.532289  0.789331 -0.122159  0.019000  1.427162
# 2      ENSG00000094914  1.605229  0.936681  0.345886  0.183699 -1.001764
# 3      ENSG00000081760  0.467196  0.690415 -0.066723  0.335478  1.017124
# 4      ENSG00000114771  0.956718  0.202132 -0.490047 -0.524460  0.467132
# ...                ...       ...       ...       ...       ...       ...
# 14893  ENSG00000198455  1.436813 -1.455513  0.510199  0.224208  0.323736
# 14894  ENSG00000070476  1.140170 -1.162868  0.551409  0.127004  0.119115
# 14895  ENSG00000162378  0.782655 -0.057857 -0.397211  0.017498 -0.135123
# 14896  ENSG00000159840  1.042306  0.183392 -0.327697  0.065425 -0.459893
# 14897  ENSG00000074755  0.553160  0.068709  0.013208  0.760541  0.592771
#
#           hpa_5     hpa_6     hpa_7     hpa_8  ...    hpa_95    hpa_96  \
# 0      1.545059 -0.450936 -0.444200 -0.116774  ...  0.169390 -0.337498
# 1     -0.065659  0.001669  0.386983 -0.028900  ... -0.161377 -0.112053
# 2     -0.846346  0.550995  0.368205  0.202731  ...  0.210805  0.036100
# 3      0.029579 -0.131714  0.212387  0.075120  ... -0.054963 -0.016087
# 4     -0.207775 -0.494652  0.192615  0.077836  ... -0.006768 -0.001066
# ...         ...       ...       ...       ...  ...       ...       ...
# 14893 -0.171141 -0.060697  0.088626  0.103071  ...  0.030362 -0.020984
# 14894 -0.120434 -0.421260  0.798186  0.041917  ...  0.030472 -0.025857
# 14895 -0.248882 -0.438176  0.113363 -0.295955  ...  0.026793  0.046815
# 14896  0.507171 -0.610148  0.067066  0.368216  ... -0.123091 -0.176505
# 14897 -0.094544  0.326136 -0.636445  0.047971  ... -0.000043 -0.011993
#
#          hpa_97    hpa_98    hpa_99  nih_ssm_in_cohort  nih_ssm_across_gdc  \
# 0      0.316335 -0.147962 -0.007512           0.049383            0.031607
# 1      0.056161 -0.032347 -0.022306           0.001764            0.009436
# 2      0.342006 -0.033900  0.423577           0.005291            0.008822
# 3      0.117175  0.116624  0.204021           0.031746            0.015036
# 4      0.007657 -0.018742  0.001135           0.010582            0.010817
# ...         ...       ...       ...                ...                 ...
# 14893  0.005424 -0.012979 -0.002219           0.024691            0.023168
# 14894  0.004240 -0.008338 -0.015161           0.014109            0.013195
# 14895  0.003799  0.011371  0.035801           0.022928            0.011891
# 14896 -0.039884 -0.090115 -0.019298           0.012346            0.011047
# 14897 -0.002164 -0.009043  0.003843           0.044092            0.035827
#
#        nih_cnv_gain  nih_cnv_loss  nih_tot_mutations
# 0          0.042885      0.066277                 29
# 1          0.048733      0.025341                  1
# 2          0.068226      0.019493                  3
# 3          0.038986      0.052632                 19
# 4          0.066277      0.011696                  6
# ...             ...           ...                ...
# 14893      0.033138      0.011696                 16
# 14894      0.033138      0.015595                 10
# 14895      0.035088      0.048733                 14
# 14896      0.064327      0.023392                  8
# 14897      0.011696      0.046784                 26
#
# [14898 rows x 106 columns]

# %% [markdown]
# Import STRING Dataset

# %%
el = ImportSTRING()
el
# Out:
# Original Size:  11938498
# After Dropping Duplicates:  5969249 (- 5969249 )
# After Merging:  5969249 (- 0 )
#
# NaN values per Column: 0 0
# New edge list size: 5969249 ( - 0 )
#                 protein1         protein2  neighborhood  fusion  cooccurence  \
# 0        ENSG00000004059  ENSG00000154678             0       0            0
# 1        ENSG00000004059  ENSG00000180370             0       0            0
# 2        ENSG00000004059  ENSG00000100228             0       0            0
# 3        ENSG00000004059  ENSG00000107263             0       0            0
# 4        ENSG00000004059  ENSG00000184900             0       0            0
# ...                  ...              ...           ...     ...          ...
# 5969244  ENSG00000279723  ENSG00000172381             0       0            0
# 5969245  ENSG00000279723  ENSG00000177853             0       0            0
# 5969246  ENSG00000268606  ENSG00000269405             0       0            0
# 5969247  ENSG00000223802  ENSG00000261832             0       0            0
# 5969248  ENSG00000181404  ENSG00000279968             0       0            0
#
#          coexpression  experimental  database  textmining  combined_score
# 0                  54             0         0         144             155
# 1                   0           180         0          61             197
# 2                  62           152         0         101             222
# 3                   0           161         0          64             181
# 4                  82           213         0          72             270
# ...               ...           ...       ...         ...             ...
# 5969244           159             0         0           0             159
# 5969245             0             0         0         181             181
# 5969246            76             0         0         283             309
# 5969247             0             0         0         218             218
# 5969248             0             0         0         320             319
#
# [5969249 rows x 10 columns]

# %% [markdown]
# Intersect Edge List (STRING) and Node Features (HPA and NIH/GDC) to Create LS-fGIN

# %%
el_allgenes = el['protein1'].append(el['protein2']).drop_duplicates()
master = master.loc[master['ensembl'].isin(el_allgenes)]
master
# Out:
#                ensembl     hpa_0     hpa_1     hpa_2     hpa_3     hpa_4  \
# 0      ENSG00000175899  0.443505  0.313574  0.430307 -0.285337 -0.351412
# 1      ENSG00000128274  0.532289  0.789331 -0.122159  0.019000  1.427162
# 2      ENSG00000094914  1.605229  0.936681  0.345886  0.183699 -1.001764
# 3      ENSG00000081760  0.467196  0.690415 -0.066723  0.335478  1.017124
# 4      ENSG00000114771  0.956718  0.202132 -0.490047 -0.524460  0.467132
# ...                ...       ...       ...       ...       ...       ...
# 14893  ENSG00000198455  1.436813 -1.455513  0.510199  0.224208  0.323736
# 14894  ENSG00000070476  1.140170 -1.162868  0.551409  0.127004  0.119115
# 14895  ENSG00000162378  0.782655 -0.057857 -0.397211  0.017498 -0.135123
# 14896  ENSG00000159840  1.042306  0.183392 -0.327697  0.065425 -0.459893
# 14897  ENSG00000074755  0.553160  0.068709  0.013208  0.760541  0.592771
#
#           hpa_5     hpa_6     hpa_7     hpa_8  ...    hpa_95    hpa_96  \
# 0      1.545059 -0.450936 -0.444200 -0.116774  ...  0.169390 -0.337498
# 1     -0.065659  0.001669  0.386983 -0.028900  ... -0.161377 -0.112053
# 2     -0.846346  0.550995  0.368205  0.202731  ...  0.210805  0.036100
# 3      0.029579 -0.131714  0.212387  0.075120  ... -0.054963 -0.016087
# 4     -0.207775 -0.494652  0.192615  0.077836  ... -0.006768 -0.001066
# ...         ...       ...       ...       ...  ...       ...       ...
# 14893 -0.171141 -0.060697  0.088626  0.103071  ...  0.030362 -0.020984
# 14894 -0.120434 -0.421260  0.798186  0.041917  ...  0.030472 -0.025857
# 14895 -0.248882 -0.438176  0.113363 -0.295955  ...  0.026793  0.046815
# 14896  0.507171 -0.610148  0.067066  0.368216  ... -0.123091 -0.176505
# 14897 -0.094544  0.326136 -0.636445  0.047971  ... -0.000043 -0.011993
#
#          hpa_97    hpa_98    hpa_99  nih_ssm_in_cohort  nih_ssm_across_gdc  \
# 0      0.316335 -0.147962 -0.007512           0.049383            0.031607
# 1      0.056161 -0.032347 -0.022306           0.001764            0.009436
# 2      0.342006 -0.033900  0.423577           0.005291            0.008822
# 3      0.117175  0.116624  0.204021           0.031746            0.015036
# 4      0.007657 -0.018742  0.001135           0.010582            0.010817
# ...         ...       ...       ...                ...                 ...
# 14893  0.005424 -0.012979 -0.002219           0.024691            0.023168
# 14894  0.004240 -0.008338 -0.015161           0.014109            0.013195
# 14895  0.003799  0.011371  0.035801           0.022928            0.011891
# 14896 -0.039884 -0.090115 -0.019298           0.012346            0.011047
# 14897 -0.002164 -0.009043  0.003843           0.044092            0.035827
#
#        nih_cnv_gain  nih_cnv_loss  nih_tot_mutations
# 0          0.042885      0.066277                 29
# 1          0.048733      0.025341                  1
# 2          0.068226      0.019493                  3
# 3          0.038986      0.052632                 19
# 4          0.066277      0.011696                  6
# ...             ...           ...                ...
# 14893      0.033138      0.011696                 16
# 14894      0.033138      0.015595                 10
# 14895      0.035088      0.048733                 14
# 14896      0.064327      0.023392                  8
# 14897      0.011696      0.046784                 26
#
# [14855 rows x 106 columns]

# %%
el_intersect = el.iloc[:, :2].merge(master["ensembl"], right_on="ensembl", left_on='protein1').drop("ensembl", axis=1)
el_intersect = el_intersect.merge(master["ensembl"], right_on="ensembl", left_on='protein2').drop("ensembl", axis=1).rename(columns={'protein1':'gene1', 'protein2':'gene2'})
el = el_intersect.merge(el, right_on=['protein1', 'protein2'], left_on=['gene1', 'gene2']).drop(['protein1','protein2'], axis=1)
el
# Out:
#                    gene1            gene2  neighborhood  fusion  cooccurence  \
# 0        ENSG00000004059  ENSG00000154678             0       0            0
# 1        ENSG00000012061  ENSG00000154678             0       0            0
# 2        ENSG00000038295  ENSG00000154678             0       0            0
# 3        ENSG00000005001  ENSG00000154678             0       0            0
# 4        ENSG00000068697  ENSG00000154678             0       0            0
# ...                  ...              ...           ...     ...          ...
# 4405636  ENSG00000256618  ENSG00000270188             0       0            0
# 4405637  ENSG00000255823  ENSG00000270188             0       0            0
# 4405638  ENSG00000256045  ENSG00000270188             0       0            0
# 4405639  ENSG00000269028  ENSG00000270188             0       0            0
# 4405640  ENSG00000270672  ENSG00000270188             0       0            0
#
#          coexpression  experimental  database  textmining  combined_score
# 0                  54             0         0         144             155
# 1                  53             0         0         246             255
# 2                  88            99         0          53             153
# 3                   0             0         0         206             205
# 4                   0             0         0         176             175
# ...               ...           ...       ...         ...             ...
# 4405636           771             0         0           0             771
# 4405637           647             0         0           0             647
# 4405638           523             0         0           0             523
# 4405639           523             0         0           0             523
# 4405640           551             0         0           0             551
#
# [4405641 rows x 10 columns]

# %%
el[['gene1', 'gene2']].to_csv('../data/final_data/ls-fgin_edge_list.edg', index=False, header=False, sep='\t') 
el.to_csv('../data/final_data/ls-fgin_edge_list_features.edg', index=False)

# %% [markdown]
# Import Disease Gene Network and Intersect with Master

# %%
dgn = ImportDGN()
dgn = dgn.loc[dgn['ensembl'].isin(master['ensembl'])]
dgn
# Out:
#              ensembl  gda_score
# 1    ENSG00000196839          1
# 7    ENSG00000153094          1
# 8    ENSG00000111252          1
# 16   ENSG00000269897          1
# 17   ENSG00000204410          1
# ..               ...        ...
# 978  ENSG00000169554          1
# 979  ENSG00000117399          1
# 980  ENSG00000116688          1
# 981  ENSG00000013364          1
# 982  ENSG00000039068          1
#
# [778 rows x 2 columns]

# %% [markdown]
# Run node2vec

# %%
network = Runnode2vec("../data/final_data/ls-fgin_edge_list.edg")
master = master.merge(network, on='ensembl')
master.to_csv("../data/final_data/node_node2vec_data.csv", index=None)
master
# Out:
# 00%|██████████████████████████████████████████████████████████████████████████| 148540.0/148540 [01:50<00:00, 1345.38it/s]
#                ensembl     hpa_0     hpa_1     hpa_2     hpa_3     hpa_4  \
# 0      ENSG00000175899  0.443505  0.313574  0.430307 -0.285337 -0.351412
# 1      ENSG00000128274  0.532289  0.789331 -0.122159  0.019000  1.427162
# 2      ENSG00000094914  1.605229  0.936681  0.345886  0.183699 -1.001764
# 3      ENSG00000081760  0.467196  0.690415 -0.066723  0.335478  1.017124
# 4      ENSG00000114771  0.956718  0.202132 -0.490047 -0.524460  0.467132
# ...                ...       ...       ...       ...       ...       ...
# 14849  ENSG00000198455  1.436813 -1.455513  0.510199  0.224208  0.323736
# 14850  ENSG00000070476  1.140170 -1.162868  0.551409  0.127004  0.119115
# 14851  ENSG00000162378  0.782655 -0.057857 -0.397211  0.017498 -0.135123
# 14852  ENSG00000159840  1.042306  0.183392 -0.327697  0.065425 -0.459893
# 14853  ENSG00000074755  0.553160  0.068709  0.013208  0.760541  0.592771
#
#           hpa_5     hpa_6     hpa_7     hpa_8  ...  network_118  network_119  \
# 0      1.545059 -0.450936 -0.444200 -0.116774  ...     0.036981     0.157335
# 1     -0.065659  0.001669  0.386983 -0.028900  ...     0.153674    -0.066952
# 2     -0.846346  0.550995  0.368205  0.202731  ...     0.060934     0.258619
# 3      0.029579 -0.131714  0.212387  0.075120  ...    -0.092571    -0.106043
# 4     -0.207775 -0.494652  0.192615  0.077836  ...    -0.044612    -0.279740
# ...         ...       ...       ...       ...  ...          ...          ...
# 14849 -0.171141 -0.060697  0.088626  0.103071  ...     0.482340     0.172590
# 14850 -0.120434 -0.421260  0.798186  0.041917  ...     0.233870     0.170742
# 14851 -0.248882 -0.438176  0.113363 -0.295955  ...     0.041925    -0.162956
# 14852  0.507171 -0.610148  0.067066  0.368216  ...     0.136820     0.166426
# 14853 -0.094544  0.326136 -0.636445  0.047971  ...     0.291244    -0.160468
#
#        network_120  network_121  network_122  network_123  network_124  \
# 0        -0.089837    -0.055205    -0.225922     0.093068    -0.157702
# 1         0.158498     0.297664    -0.001066     0.226190     0.174964
# 2        -0.262822    -0.089166    -0.255628    -0.277086    -0.210965
# 3        -0.232718     0.002393    -0.175173     0.129388     0.117625
# 4        -0.045430    -0.122584    -0.047974    -0.237839     0.220174
# ...            ...          ...          ...          ...          ...
# 14849    -0.058368     0.341189    -0.255164    -0.086852    -0.218874
# 14850    -0.085968     0.136808     0.307713    -0.080580    -0.221730
# 14851    -0.004561     0.097026    -0.350563    -0.162661     0.087416
# 14852    -0.237456     0.001832     0.022884     0.103599     0.083706
# 14853    -0.009085     0.066561     0.191802    -0.006277    -0.271046
#
#        network_125  network_126  network_127
# 0         0.095782    -0.129805     0.138554
# 1        -0.375302    -0.052360    -0.001032
# 2         0.383674    -0.199323    -0.037371
# 3        -0.209757     0.081049     0.102885
# 4        -0.345824    -0.205772     0.036599
# ...            ...          ...          ...
# 14849     0.217625    -0.008126     0.173057
# 14850     0.050049     0.374102    -0.208463
# 14851     0.127323    -0.253828     0.204887
# 14852     0.149081    -0.279210     0.043170
# 14853    -0.199538    -0.001728     0.186505
#
# [14854 rows x 234 columns]

# %%
label_col = 'gda_score'

node_dataset = dgn.merge(master['ensembl'], on='ensembl', how='right').fillna(0)

node_dataset[label_col] = node_dataset[label_col].map({0: pd.NA, 1:1})

print('# of positive labels: ', node_dataset[label_col].sum())

node_dataset

labels = node_dataset

labels[label_col] = labels[label_col].astype('Int64')

num_neg_samples = node_dataset[label_col].sum()

unlabeled_samples = labels.loc[labels['gda_score'].fillna(0)!=1]

num_random_samplings = 100
for i in range(num_random_samplings):
    negative_samples = np.random.choice(unlabeled_samples['ensembl'], size=num_neg_samples, replace=False)
    labels[f'label_{i}'] = labels[label_col]
    labels.loc[labels['ensembl'].isin(negative_samples), f'label_{i}'] = 0
labels
# Out:
# # of positive labels:  778
#                ensembl  gda_score  label_0  label_1  label_2  label_3  \
# 0      ENSG00000175899       <NA>     <NA>     <NA>     <NA>     <NA>
# 1      ENSG00000128274       <NA>     <NA>     <NA>     <NA>     <NA>
# 2      ENSG00000094914       <NA>        0     <NA>     <NA>     <NA>
# 3      ENSG00000081760       <NA>     <NA>     <NA>     <NA>     <NA>
# 4      ENSG00000114771       <NA>     <NA>     <NA>     <NA>        0
# ...                ...        ...      ...      ...      ...      ...
# 14849  ENSG00000198455       <NA>        0     <NA>     <NA>     <NA>
# 14850  ENSG00000070476       <NA>     <NA>     <NA>     <NA>     <NA>
# 14851  ENSG00000162378       <NA>     <NA>     <NA>     <NA>     <NA>
# 14852  ENSG00000159840       <NA>     <NA>     <NA>     <NA>     <NA>
# 14853  ENSG00000074755       <NA>     <NA>     <NA>     <NA>     <NA>
#
#        label_4  label_5  label_6  label_7  ...  label_90  label_91  label_92  \
# 0         <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 1         <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 2         <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 3         <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 4         <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>         0
# ...        ...      ...      ...      ...  ...       ...       ...       ...
# 14849     <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 14850     <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 14851     <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 14852     <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 14853     <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
#
#        label_93  label_94  label_95  label_96  label_97  label_98  label_99
# 0          <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 1          <NA>      <NA>      <NA>      <NA>      <NA>      <NA>         0
# 2          <NA>      <NA>      <NA>         0         0      <NA>      <NA>
# 3          <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 4          <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# ...         ...       ...       ...       ...       ...       ...       ...
# 14849      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 14850      <NA>      <NA>      <NA>      <NA>      <NA>         0      <NA>
# 14851      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 14852      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 14853      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
#
# [14854 rows x 102 columns]

# %%
labels.to_csv("../data/final_data/training_labels_trials.csv", index=None)
